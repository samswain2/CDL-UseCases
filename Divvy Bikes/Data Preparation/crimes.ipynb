# %%
import pandas as pd
import numpy as np
from geographic import addGeographic

df = pd.read_csv('Crimes.csv')

# %%
df.head(5)
# Out:
#          ID Case Number                    Date                  Block  IUCR  \
# 0  10224738    HY411648  09/05/2015 01:30:00 PM        043XX S WOOD ST  0486
# 1  10224739    HY411615  09/04/2015 11:30:00 AM    008XX N CENTRAL AVE  0870
# 2  11646166    JC213529  09/01/2018 12:01:00 AM  082XX S INGLESIDE AVE  0810
# 3  10224740    HY411595  09/05/2015 12:45:00 PM      035XX W BARRY AVE  2023
# 4  10224741    HY411610  09/05/2015 01:00:00 PM    0000X N LARAMIE AVE  0560
#
#   Primary Type              Description Location Description  Arrest  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE   False
# 1        THEFT           POCKET-PICKING              CTA BUS   False
# 2        THEFT                OVER $500            RESIDENCE   False
# 3    NARCOTICS    POSS: HEROIN(BRN/TAN)             SIDEWALK    True
# 4      ASSAULT                   SIMPLE            APARTMENT   False
#
#    Domestic  ...  Ward  Community Area  FBI Code  X Coordinate Y Coordinate  \
# ...

# %%
df = df.dropna()

# %%
len(df)
# Out:
# 7016121

# %%
from geographic import addGeographic
lat = df['Latitude']
lon = df['Longitude']
new_df = addGeographic(df.iloc[0:11], lat[:11], lon[:11])
# Out:
# /tmp/ipykernel_1133878/2264372547.py:4: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   new_df = addGeographic(df.iloc[0:11], lat[:11], lon[:11])

# %%
final_df = pd.DataFrame()
for i in range(len(df)):
    left =

# %%
new_df
# Out:
#           ID Case Number                    Date                    Block  \
# 0   10224738    HY411648  09/05/2015 01:30:00 PM          043XX S WOOD ST
# 1   10224739    HY411615  09/04/2015 11:30:00 AM      008XX N CENTRAL AVE
# 3   10224740    HY411595  09/05/2015 12:45:00 PM        035XX W BARRY AVE
# 4   10224741    HY411610  09/05/2015 01:00:00 PM      0000X N LARAMIE AVE
# 5   10224742    HY411435  09/05/2015 10:55:00 AM      082XX S LOOMIS BLVD
# 6   10224743    HY411629  09/04/2015 06:00:00 PM     021XX W CHURCHILL ST
# 7   10224744    HY411605  09/05/2015 01:00:00 PM        025XX W CERMAK RD
# 8   10224745    HY411654  09/05/2015 11:30:00 AM  031XX W WASHINGTON BLVD
# 10  10224746    HY411662  09/05/2015 02:00:00 PM       071XX S PULASKI RD
# 11  10224749    HY411626  09/05/2015 11:00:00 AM    052XX N MILWAUKEE AVE
# 12  10224750    HY411632  09/05/2015 03:00:00 AM         0000X W 103RD ST
#
#     IUCR   Primary Type              Description  \
# ...

# %%
new_df.iloc[10]
# Out:
# ID                                           10224750
# Case Number                                  HY411632
# Date                           09/05/2015 03:00:00 AM
# Block                                0000X W 103RD ST
# IUCR                                             2820
# Primary Type                            OTHER OFFENSE
# Description                          TELEPHONE THREAT
# Location Description                        APARTMENT
# Arrest                                          False
# Domestic                                         True
# Beat                                              512
# District                                          5.0
# Ward                                             34.0
# Community Area                                   49.0
# FBI Code                                           26
# X Coordinate                                1177871.0
# Y Coordinate                                1836676.0
# ...

# %%
for i in range(6):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
import math
nrow = len(df.iloc[0:11])
test_df = df.iloc[0:11]
chunk_size = 2
lat_new = df['Latitude'][0:11]
long_new = df['Longitude'][0:11]
for i in range(math.ceil(nrow / chunk_size)):
            if i * chunk_size > nrow or (i+1) * chunk_size > nrow:
                final_j = nrow - 1
            else: 
                final_j = (i+1) * chunk_size
            print(final_j)
            curr_chunk = test_df[i * chunk_size:final_j]
            curr_lat = lat_new[i * chunk_size:final_j]
            curr_lon = long_new[i * chunk_size:final_j]
            print([curr_chunk['ID'], curr_lat, curr_lon])
# Out:
# 2
# [0    10224738
# 1    10224739
# Name: ID, dtype: int64, 0    41.815117
# 1    41.895080
# Name: Latitude, dtype: float64, 0   -87.6700
# 1   -87.7654
# Name: Longitude, dtype: float64]
# 4
# [3    10224740
# 4    10224741
# Name: ID, dtype: int64, 3    41.937406
# 4    41.881903
# Name: Latitude, dtype: float64, 3   -87.716650
# 4   -87.755121
# Name: Longitude, dtype: float64]
# 6
# [5    10224742
# 6    10224743
# Name: ID, dtype: int64, 5    41.744379
# 6    41.914636
# Name: Latitude, dtype: float64, 5   -87.658431
# 6   -87.681631
# Name: Longitude, dtype: float64]
# 8
# [7    10224744
# 8    10224745
# Name: ID, dtype: int64, 7    41.851989
# 8    41.882814
# Name: Latitude, dtype: float64, 7   -87.689219
# 8   -87.704326
# Name: Longitude, dtype: float64]
# 10
# [10    10224746
# 11    10224749
# Name: ID, dtype: int64, 10    41.763648
# 11    41.975968
# Name: Latitude, dtype: float64, 10   -87.722345
# 11   -87.768014
# Name: Longitude, dtype: float64]
# 10
# ...

# %%
test_df
# Out:
#           ID Case Number                    Date                    Block  \
# 0   10224738    HY411648  09/05/2015 01:30:00 PM          043XX S WOOD ST
# 1   10224739    HY411615  09/04/2015 11:30:00 AM      008XX N CENTRAL AVE
# 3   10224740    HY411595  09/05/2015 12:45:00 PM        035XX W BARRY AVE
# 4   10224741    HY411610  09/05/2015 01:00:00 PM      0000X N LARAMIE AVE
# 5   10224742    HY411435  09/05/2015 10:55:00 AM      082XX S LOOMIS BLVD
# 6   10224743    HY411629  09/04/2015 06:00:00 PM     021XX W CHURCHILL ST
# 7   10224744    HY411605  09/05/2015 01:00:00 PM        025XX W CERMAK RD
# 8   10224745    HY411654  09/05/2015 11:30:00 AM  031XX W WASHINGTON BLVD
# 10  10224746    HY411662  09/05/2015 02:00:00 PM       071XX S PULASKI RD
# 11  10224749    HY411626  09/05/2015 11:00:00 AM    052XX N MILWAUKEE AVE
# 12  10224750    HY411632  09/05/2015 03:00:00 AM         0000X W 103RD ST
#
#     IUCR   Primary Type              Description  \
# ...

# %%
from more_itertools import sliced
CHUNK_SIZE = 5

index_slices = sliced(range(len(df)), CHUNK_SIZE)

for index_slice in index_slices:
  chunk = test_df.iloc[index_slice]
  print(chunk) # your dataframe chunk ready for use
# Out:
#          ID Case Number                    Date                Block  IUCR  \
# 0  10224738    HY411648  09/05/2015 01:30:00 PM      043XX S WOOD ST  0486
# 1  10224739    HY411615  09/04/2015 11:30:00 AM  008XX N CENTRAL AVE  0870
# 3  10224740    HY411595  09/05/2015 12:45:00 PM    035XX W BARRY AVE  2023
# 4  10224741    HY411610  09/05/2015 01:00:00 PM  0000X N LARAMIE AVE  0560
# 5  10224742    HY411435  09/05/2015 10:55:00 AM  082XX S LOOMIS BLVD  0610
#
#   Primary Type              Description Location Description  Arrest  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE   False
# 1        THEFT           POCKET-PICKING              CTA BUS   False
# 3    NARCOTICS    POSS: HEROIN(BRN/TAN)             SIDEWALK    True
# 4      ASSAULT                   SIMPLE            APARTMENT   False
# 5     BURGLARY           FORCIBLE ENTRY            RESIDENCE   False
#
#    Domestic  ...  Ward  Community Area  FBI Code  X Coordinate Y Coordinate  \
# ...

# %%
d = np.array_split(test_df, 3)

# %%
np.array_split(lat_new, 3)
# Out:
# /home/henry/workspace/fitx-env/lib/python3.10/site-packages/numpy/lib/shape_base.py:790: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sub_arys.append(_nx.swapaxes(sary[st:end], axis, 0))
# [0    41.815117
#  1    41.895080
#  3    41.937406
#  4    41.881903
#  Name: Latitude, dtype: float64,
#  5    41.744379
#  6    41.914636
#  7    41.851989
#  8    41.882814
#  Name: Latitude, dtype: float64,
#  10    41.763648
#  11    41.975968
#  12    41.707155
#  Name: Latitude, dtype: float64]

# %%
len(d)
# Out:
# 3
